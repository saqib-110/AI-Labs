# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Flatten, Dropout, Dense
import matplotlib.pyplot as plt

# Loading Data
(train_img, train_lab), (test_img, test_lab) = cifar10.load_data()

# Classifying the images
class_names = ["airplane", "automobile", "bird", "cat", "deer", "dog", "frog", "horse", "ship", "truck"]

# Setting up the images
plt.figure(figsize=(10, 10))
for i in range(9):
    plt.subplot(3, 3, i + 1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_img[i])
    plt.xlabel(class_names[train_lab[i][0]])

plt.show()
# Out:
# A local file was found, but it seems to be incomplete or outdated because the auto file hash does not match the original value of 6d958be074577803d12ecdefd02955f39262c83c16fe9348329d7fe0b5c001ce so we will re-download the data.
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 508s 3us/step

# %%
# Initializing the model
model = Sequential()

# Adding the first convolutional layer
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))

# Adding the first pooling layer
model.add(MaxPool2D((2, 2)))

# Adding a dropout layer to prevent overfitting
model.add(Dropout(0.2))

# Adding the second convolutional layer
model.add(Conv2D(64, (3, 3), activation='relu'))

# Adding the second pooling layer
model.add(MaxPool2D((2, 2)))

# Adding another dropout layer
model.add(Dropout(0.2))

# Adding a fully connected layer
model.add(Flatten())
model.add(Dense(128, activation='relu'))

# Adding the output layer
model.add(Dense(10, activation='softmax'))

# Compiling the model
model.compile(optimizer='adam', 
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])

# Training the model
history = model.fit(train_img, train_lab, epochs=10, validation_data=(test_img, test_lab))
# Out:
# Epoch 1/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.1946 - loss: 4.9335 - val_accuracy: 0.4382 - val_loss: 1.5242
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.4293 - loss: 1.5526 - val_accuracy: 0.5093 - val_loss: 1.3570
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.5274 - loss: 1.3294 - val_accuracy: 0.5342 - val_loss: 1.3375
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.5757 - loss: 1.2035 - val_accuracy: 0.6142 - val_loss: 1.1159
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.6124 - loss: 1.1161 - val_accuracy: 0.6306 - val_loss: 1.0952
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.6348 - loss: 1.0552 - val_accuracy: 0.6492 - val_loss: 1.0270
# Epoch 7/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.6530 - loss: 1.0055 - val_accuracy: 0.6538 - val_loss: 1.0144
# Epoch 8/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.6657 - loss: 0.9623 - val_accuracy: 0.6454 - val_loss: 1.0512
# Epoch 9/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.6793 - loss: 0.9255 - val_accuracy: 0.6631 - val_loss: 1.0141
# Epoch 10/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.6834 - loss: 0.9079 - val_accuracy: 0.6390 - val_loss: 1.0550
